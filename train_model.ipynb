# %%
import nltk
import json
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import random
import warnings
warnings.filterwarnings('ignore')

# %%
nltk.download('punkt')
nltk.download('wordnet')

stemmer = WordNetLemmatizer()
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Vishnu
# [nltk_data]     Priya\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to C:\Users\Vishnu
# [nltk_data]     Priya\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
with open("intents_big.json", "r") as f:
    intents = json.load(f)

# %%
words = []
classes = []
documents = []
ignore_words = ['?']

for intent in intents['intents']:
    if 'pattern' in intent:  # Check if the key exists
        for pattern in intent['pattern']:
            # Tokenize each word in the sentence
            w = nltk.word_tokenize(pattern)
            # Add to our words list
            words.extend(w)
            # Add to documents in our corpus
            documents.append((w, intent['tag']))
            # Add to our classes list
            if intent['tag'] not in classes:
                classes.append(intent['tag'])
    else:
        print(f"Warning: 'patterns' key missing in intent: {intent}")
        
words = [stemmer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))
classes = sorted(list(set(classes)))

print(len(documents), "documents")
print(len(classes), "classes", classes)
print(len(words), "unique lemmatized words", words)
# Out:
# 14479 documents
# 90 classes ['Acidic Soil', 'Agriculture', 'Alkaline Soil', 'Aphid Infestation', 'Arid Climate', 'Beans', 'Beneficial Insects', 'Cabbage', 'Carrots', 'Chemical_Pest_Control', 'Clay Soil', 'Cold Climate', 'Companion Planting', 'Cover Crops', 'Crop Rotation', 'Crop_Rotation', 'Cucumbers', 'Diatomaceous Earth', 'Disease_Management', 'Fungal Disease Prevention', 'Garlic', 'Garlic and Chili Spray', 'Grains', 'Handpicking', 'Harvesting_Practices', 'Herbs', 'Identifying_Pests', 'Insecticidal Soap', 'Integrated_Pest_Management', 'Irrigation Management', 'Irrigation_Strategies', 'Legumes', 'Lettuce', 'Loamy Soil', 'Marigolds', 'Melons', 'Mulching', 'Neem Oil', 'Nutrient_Management', 'Organic Matter Addition', 'Organic_Pest_Control', 'Peppers', 'Pest_Control', 'Plant_Diseases', 'Planting_Techniques', 'Powdery Mildew', 'Preventative_Measures', 'Regular Testing', 'Root Crops', 'Row Covers', 'Sandy Soil', 'Soil Amendments', 'Specific_Pest_Issues', 'Spider Mites Control', 'Temperate Climate', 'Tomatoes', 'Tropical Climate', 'Viral Disease Response', 'agricultural_techniques', 'casual_greeting', 'climate_resilient_farming', 'cotton', 'creator', 'crop_prices', 'crop_selection', 'crop_selection_india', 'farewell', 'farmer_assistance', 'good_afternoon', 'good_evening', 'good_morning', 'greeting', 'identity', 'irrigation_methods', 'livestock_management', 'loans', 'onions', 'organic_farming', 'pH Adjustment', 'pest_management', 'rice', 'schemes', 'soil_health_management_india', 'soil_management', 'sorry', 'sugarcane', 'technology_in_agriculture', 'thank_you', 'unrecognized_input', 'weather_forecast']
# 513 unique lemmatized words ['!', "'m", "'s", '(', ')', '*', ',', '-', '.', '/', '0', '1', '3', '8', '@', 'a', 'about', 'adapting', 'adopt', 'advantage', 'advice', 'affect', 'afternoon', 'agricultural', 'agriculture', 'alternative', 'amendment', 'an', 'and', 'andhra', 'animal', 'answer', 'ant', 'any', 'anyone', 'aphid', 'apology', 'apple', 'apply', 'are', 'around', 'ask', 'assist', 'assistance', 'available', 'b', 'based', 'be', 'bean', 'bed', 'beginner', 'being', 'beneficial', 'benefit', 'best', 'between', 'bima', 'bird', 'black', 'blight', 'bonjour', 'brings', 'brown', 'bug', 'bulb', 'bump', 'bush', 'by', 'bye', 'c', 'cabbage', 'call', 'can', 'capable', 'card', 'caterpillar', 'cause', 'central', 'change', 'changing', 'chat', 'chatbot', 'chemical', 'child', 'choose', 'choosing', 'ciao', 'climate', 'climate-resilient', 'climate-smart', 'common', 'companion', 'compost', 'concerned', 'condition', 'conserve', 'consider', 'control', 'controlling', 'conventional', 'corn', 'cotton', 'could', 'cover', 'created', 'creature', 'credit', 'crop', 'cucumber', 'cultivation', 'current', 'd', 'damaging', 'day', 'dealing', 'deep', 'deer', 'deficient', 'depletion', 'deter', 'determine', 'developer', 'digging', 'disadvantage', 'discolored', 'disease', 'do', 'doe', 'doing', 'dot', 'drone', 'droopy', 'drought', 'dry', 'during', 'e', 'eaten', 'eating', 'eco-friendly', 'effective', 'effectively', 'efficient', 'efficiently', 'enrichment', 'ensure', 'environmental', 'erosion', 'essential', 'evening', 'event', 'every', 'expected', 'explore', 'extreme', 'f', 'factor', 'farm', 'farmer', 'farming', 'fasal', 'fertility', 'fertilizer', 'find', 'finding', 'flower', 'fly', 'for', 'forecast', 'found', 'fresh', 'from', 'frost', 'fruit', 'fungal', 'fungicide', 'g', 'garden', 'get', 'going', 'good', 'goodbye', 'government', 'great', 'greeting', 'grow', 'growing', 'growth', 'grub', 'guidance', 'guide', 'gujarat', 'h', 'happening', 'harming', 'harvest', 'harvested', 'harvesting', 'have', 'health', 'healthy', 'heard', 'hello', 'help', 'herb', 'herbicide', 'here', 'hey', 'heyy', 'hi', 'hiya', 'hola', 'hole', 'horticulture', 'house', 'houseplant', 'hovering', 'how', 'howdy', 'husbandry', 'i', 'identify', 'if', 'impact', 'implement', 'improve', 'in', 'increase', 'india', 'infestation', 'information', 'insect', 'insecticide', 'instead', 'integrated', 'integrating', 'introduce', 'invading', 'irrigate', 'irrigating', 'irrigation', 'is', 'it', 'j', 'jumping', 'k', 'karnataka', 'keep', 'kharif', 'kind', 'kisan', 'know', 'konnichiwa', 'l', 'ladybug', 'later', 'lawn', 'leaf', 'let', 'lettuce', 'level', 'like', 'livestock', 'loan', 'location', 'long', 'longer', 'looking', 'm', 'made', 'maharashtra', 'maintain', 'maintaining', 'make', 'manage', 'management', 'mantri', 'market', 'maximum', 'me', 'measure', 'melon', 'method', 'might', 'mildew', 'mind', 'mission', 'mite', 'modern', 'mole', 'monitor', 'monsoon', 'more', 'morning', 'morning/afternoon/evening', 'most', 'moving', 'much', 'my', 'n', 'nadu', 'namaste', 'name', 'national', 'natural', 'naturally', 'need', 'neem', 'nematode', 'new', 'newly', 'nitrogen', 'north', 'nutrient', 'o', 'of', 'often', 'oil', 'on', 'onion', 'optimal', 'or', 'organic', 'other', 'out', 'over', 'overripe', 'overwatered', 'p', 'per', 'pest', 'pesticide', 'pet', 'picking', 'plant', 'planted', 'planting', 'pleasure', 'population', 'potato', 'potted', 'powdery', 'practice', 'pradesh', 'pradhan', 'precision', 'prepare', 'prevent', 'preventative', 'preventing', 'price', 'problem', 'proper', 'provide', 'punjab', 'q', 'query', 'question', 'r', 'rabbit', 'rain', 'raising', 'rate', 'recommended', 'region', 'resilient', 'resource', 'responsible', 'rice', 'rid', 'right', 'ripe', 'rise', 'root', 'rose', 'rot', 'rotate', 'rotation', 's', 'safe', 'safest', 'salaam', 'salutation', 'same', 'scheme', 'season', 'see', 'seed', 'seeing', 'seem', 'selecting', 'selection', 'selling', 'service', 'severe', 'shalom', 'should', 'sign', 'slug', 'small', 'small-scale', 'soil', 'so ...

# %%
import pickle
with open('words.pkl', 'wb') as f:
    pickle.dump(words, f)
with open('classes.pkl', 'wb') as f:
    pickle.dump(classes, f)

# %%
training = []
output = []
output_empty = [0] * len(classes)

# Training set, bag of words for each sentence
for doc in documents:
    # Initialize our bag of words
    bag = []
    # List of tokenized words for the pattern
    pattern_words = doc[0]
    # Lemmatize each word
    pattern_words = [stemmer.lemmatize(word.lower()) for word in pattern_words]
    # Create our bag of words array
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)

    # Output is a '0' for each tag and '1' for the current tag
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1

    training.append([bag, output_row])

random.shuffle(training)

# %%
def synonym_replacement(tokens, limit):
    augmented_sentences = []
    for i in range(len(tokens)):
        synonyms = []
        for syn in wordnet.synsets(tokens[i]):
            for lemma in syn.lemmas():
                synonyms.append(lemma.name())
        if len(synonyms) > 0:
            num_augmentations = min(limit, len(synonyms))
            sampled_synonyms = random.sample(synonyms, num_augmentations)
            for synonym in sampled_synonyms:
                augmented_tokens = tokens[:i] + [synonym] + tokens[i + 1:]
                augmented_sentences.append(' '.join(augmented_tokens))
    return augmented_sentences

# %%
# Augment the training data using synonym replacement
augmented_data = []
limit_per_tag = 100

for i, doc in enumerate(training):
    bag, output_row = doc
    tokens = [words[j] for j in range(len(words)) if bag[j] == 1]
    augmented_sentences = synonym_replacement(tokens, limit_per_tag)
    for augmented_sentence in augmented_sentences:
        augmented_bag = [1 if augmented_sentence.find(word) >= 0 else 0 for word in words]
        augmented_data.append([augmented_bag, output_row])


combined_data = np.concatenate((training, augmented_data), axis=0)
random.shuffle(combined_data)

from sklearn.model_selection import train_test_split

# %%
def separate_data_by_tags(data):
    data_by_tags = {}
    for d in data:
        tag = tuple(d[1])
        if tag not in data_by_tags:
            data_by_tags[tag] = []
        data_by_tags[tag].append(d)
    return data_by_tags.values()


separated_data = separate_data_by_tags(combined_data)

# %%
from sklearn.model_selection import train_test_split
# Lists to store training and testing data
training_data = []
testing_data = []

# Split each tag's data into training and testing sets
combined_data = []
for tag_data in separated_data:
    combined_data.extend(tag_data)

if len(combined_data) > 1:
    train_data, test_data = train_test_split(combined_data, test_size=0.2, random_state=42)
    training_data.extend(train_data)
    testing_data.extend(test_data)
else:
    print("Insufficient data for splitting.")


random.shuffle(training_data)
random.shuffle(testing_data)

# Convert training and testing data back to np.array
train_x = np.array([d[0] for d in training_data])
train_y = np.array([d[1] for d in training_data])
test_x = np.array([d[0] for d in testing_data])
test_y = np.array([d[1] for d in testing_data])

# %%
class NeuralNetwork(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(NeuralNetwork, self).__init__()
        self.fc1 = nn.Linear(input_size, hidden_size)
        self.relu1 = nn.ReLU()
        self.bn1 = nn.BatchNorm1d(hidden_size)
        self.dropout1 = nn.Dropout(0.2)

        self.fc2 = nn.Linear(hidden_size, hidden_size)
        self.relu2 = nn.ReLU()
        self.bn2 = nn.BatchNorm1d(hidden_size)
        self.dropout2 = nn.Dropout(0.2)

        self.fc3 = nn.Linear(hidden_size, output_size)
        self.softmax = nn.Softmax(dim=1)

    def forward(self, x):
        x = self.fc1(x)
        x = self.relu1(x)
        x = self.bn1(x)
        x = self.dropout1(x)

        x = self.fc2(x)
        x = self.relu2(x)
        x = self.bn2(x)
        x = self.dropout2(x)

        x = self.fc3(x)
        output = self.softmax(x)
        return output

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = self.fc3(x)
        return self.softmax(x)

# %%
class CustomDataset(Dataset):
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __len__(self):
        return len(self.x)

    def __getitem__(self, idx):
        return self.x[idx], self.y[idx]

# %%
def accuracy(predictions, targets):
    predicted_labels = torch.argmax(predictions, dim=1)
    true_labels = torch.argmax(targets, dim=1)
    correct = (predicted_labels == true_labels).sum().item()
    total = targets.size(0)
    return correct / total

# %%
def test_model(model, test_loader, criterion):
    model.eval()
    total_loss = 0.0
    total_accuracy = 0.0
    num_batches = len(test_loader)

    with torch.no_grad():
        for inputs, targets in test_loader:
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            total_loss += loss.item() * inputs.size(0)
            total_accuracy += accuracy(outputs, targets) * inputs.size(0)

    average_loss = total_loss / len(test_loader.dataset)
    average_accuracy = total_accuracy / len(test_loader.dataset)
    return average_loss, average_accuracy

# %%
# Create DataLoader for training and testing data
train_x = torch.tensor(train_x).float()
train_y = torch.tensor(train_y).float()
test_x = torch.tensor(test_x).float()
test_y = torch.tensor(test_y).float()

batch_size = 64
train_dataset = CustomDataset(train_x, train_y)
test_dataset = CustomDataset(test_x, test_y)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# Define the model, loss function, and optimizer
input_size = len(train_x[0])
hidden_size = 8
output_size = len(train_y[0])
model = NeuralNetwork(input_size, hidden_size, output_size)
criterion = nn.BCELoss()
optimizer = optim.Adam(model.parameters())

# %%
# Train the model and evaluate on the testing set
num_epochs = 250
for epoch in range(num_epochs):
    # Training
    model.train()
    running_loss = 0.0
    running_acc = 0.0
    for inputs, targets in train_loader:
        # Forward pass
        outputs = model(inputs)
        loss = criterion(outputs, targets)

        # Backward pass and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        # Update statistics
        running_loss += loss.item() * inputs.size(0)
        running_acc += accuracy(outputs, targets) * inputs.size(0)

    # Calculate average training loss and accuracy for the epoch
    epoch_loss = running_loss / len(train_loader.dataset)
    epoch_acc = running_acc / len(train_loader.dataset)

    # Print training loss and accuracy for each epoch
    print(f"Epoch [{epoch+1}/{num_epochs}], Training Loss: {epoch_loss:.4f}, Training Accuracy: {epoch_acc:.4f}")

    # Evaluate on the testing set
    test_loss, test_accuracy = test_model(model, test_loader, criterion)
    print(f"Epoch [{epoch+1}/{num_epochs}], Testing Loss: {test_loss:.4f}, Testing Accuracy: {test_accuracy:.4f}")
# Out:
# Epoch [1/250], Training Loss: 0.0201, Training Accuracy: 0.7861
# Epoch [1/250], Testing Loss: 0.0163, Testing Accuracy: 0.8165
# Epoch [2/250], Training Loss: 0.0151, Training Accuracy: 0.8367
# Epoch [2/250], Testing Loss: 0.0144, Testing Accuracy: 0.8535
# Epoch [3/250], Training Loss: 0.0136, Training Accuracy: 0.8677
# Epoch [3/250], Testing Loss: 0.0135, Testing Accuracy: 0.8683
# Epoch [4/250], Training Loss: 0.0131, Training Accuracy: 0.8753
# Epoch [4/250], Testing Loss: 0.0132, Testing Accuracy: 0.8746
# Epoch [5/250], Training Loss: 0.0129, Training Accuracy: 0.8786
# Epoch [5/250], Testing Loss: 0.0131, Testing Accuracy: 0.8767
# Epoch [6/250], Training Loss: 0.0128, Training Accuracy: 0.8801
# Epoch [6/250], Testing Loss: 0.0130, Testing Accuracy: 0.8777
# Epoch [7/250], Training Loss: 0.0127, Training Accuracy: 0.8811
# Epoch [7/250], Testing Loss: 0.0129, Testing Accuracy: 0.8790
# Epoch [8/250], Training Loss: 0.0126, Training Accuracy: 0.8817
# Epoch [8/250], Testing Loss: 0.0129, Testing Accuracy: 0.8791
# Epoch [9/250], Training Loss: 0.0126, Training Accuracy: 0.8821
# Epoch [9/250], Testing Loss: 0.0128, Testing Accuracy: 0.8798
# Epoch [10/250], Training Loss: 0.0126, Training Accuracy: 0.8824
# Epoch [10/250], Testing Loss: 0.0128, Testing Accuracy: 0.8799
# Epoch [11/250], Training Loss: 0.0125, Training Accuracy: 0.8827
# Epoch [11/250], Testing Loss: 0.0128, Testing Accuracy: 0.8802
# Epoch [12/250], Training Loss: 0.0125, Training Accuracy: 0.8831
# Epoch [12/250], Testing Loss: 0.0127, Testing Accuracy: 0.8806
# Epoch [13/250], Training Loss: 0.0125, Training Accuracy: 0.8832
# Epoch [13/250], Testing Loss: 0.0127, Testing Accuracy: 0.8807
# Epoch [14/250], Training Loss: 0.0125, Training Accuracy: 0.8833
# Epoch [14/250], Testing Loss: 0.0127, Testing Accuracy: 0.8808
# Epoch [15/250], Training Loss: 0.0125, Training Accuracy: 0.8835
# Epoch [15/250], Testing Loss: 0.0127, Testing Accuracy: 0.8807
# Epoch [16/250], Training Loss: 0.0125, Training Accuracy: 0.8836
# Epoch [16/250], Testing Loss: 0.0127, Testing Accuracy: 0.8812
# Epoch [17/250], Training Loss: 0.0125, Training Accuracy: 0.8836
# Epoch [17/250], Testing Loss: 0.0127, Testing Accuracy: 0.8810
# Epoch [18/250], Training Loss: 0.0124, Training Accuracy: 0.8837
# Epoch [18/250], Testing Loss: 0.0127, Testing Accuracy: 0.8812
# Epoch [19/250], Training Loss: 0.0124, Training Accuracy: 0.8836
# Epoch [19/250], Testing Loss: 0.0126, Testing Accuracy: 0.8815
# Epoch [20/250], Training Loss: 0.0124, Training Accuracy: 0.8838
# Epoch [20/250], Testing Loss: 0.0127, Testing Accuracy: 0.8813
# Epoch [21/250], Training Loss: 0.0124, Training Accuracy: 0.8838
# Epoch [21/250], Testing Loss: 0.0127, Testing Accuracy: 0.8817
# Epoch [22/250], Training Loss: 0.0124, Training Accuracy: 0.8840
# Epoch [22/250], Testing Loss: 0.0126, Testing Accuracy: 0.8814
# Epoch [23/250], Training Loss: 0.0124, Training Accuracy: 0.8839
# Epoch [23/250], Testing Loss: 0.0127, Testing Accuracy: 0.8813
# Epoch [24/250], Training Loss: 0.0124, Training Accuracy: 0.8840
# Epoch [24/250], Testing Loss: 0.0126, Testing Accuracy: 0.8817
# Epoch [25/250], Training Loss: 0.0124, Training Accuracy: 0.8840
# Epoch [25/250], Testing Loss: 0.0126, Testing Accuracy: 0.8812
# Epoch [26/250], Training Loss: 0.0124, Training Accuracy: 0.8842
# Epoch [26/250], Testing Loss: 0.0126, Testing Accuracy: 0.8816
# Epoch [27/250], Training Loss: 0.0124, Training Accuracy: 0.8840
# Epoch [27/250], Testing Loss: 0.0127, Testing Accuracy: 0.8814
# Epoch [28/250], Training Loss: 0.0124, Training Accuracy: 0.8842
# Epoch [28/250], Testing Loss: 0.0126, Testing Accuracy: 0.8814
# Epoch [29/250], Training Loss: 0.0124, Training Accuracy: 0.8842
# Epoch [29/250], Testing Loss: 0.0127, Testing Accuracy: 0.8811
# Epoch [30/250], Training Loss: 0.0124, Training Accuracy: 0.8842
# Epoch [30/250], Testing Loss: 0.0126, Testing Accuracy: 0.8814
# Epoch [31/250], Training Loss: 0.0124, Training Accuracy: 0.8843
# Epoch [31/250], Testing Loss: 0.0126, Testing Accuracy: 0.8817
# Epoch [32/250], Training Loss: 0.0124, Training Accuracy: 0.8843
# Epoch [32/250], Testing Loss: 0.0126, Testing Accuracy: 0.8819
# Epoch [33/250], Training Loss: 0.0124, Training Accuracy: 0.8843
# Epoch [33/250], Testing Loss: 0.0126, Testing Accuracy: 0.8818
# Epoch [34/250], Training Loss: 0.0124, Training Accuracy: 0.8843
# Epoch [34/250], Testing Loss: 0.0126, Testing Accuracy: 0.8817
# Epoch [35/250], Training Loss: 0.0124, Training Accuracy: 0.8843
# Epoch [35/250], Testing Loss: 0.0126, Testing Accuracy: 0.8817
# Epoch [36/250], Training Loss: 0.0124, Training Accuracy: 0.8843
# Epoch [36/250], Testing Loss: 0.0126, Testing Accuracy: 0.8817
# Epoch [37/250], Training Loss: 0.0124, Training Accuracy: 0.8844
# Epoch [37/250], Testing Loss: 0.0126, Testing Accuracy: 0.8817
# Epoch [38/250], Training Loss: 0.0124, Training Accuracy: 0.8843
# Epoch [38/250], Testing Loss: 0.0126, Testing Accuracy: 0.8818
# Epoch [39/250], Training Loss: 0.0123, Training Accuracy: 0.8844
# Epoch [39/250], Testing Loss: 0.0126, Testing Accuracy: 0.8817
# Epoch [40/250], Training Loss: 0.0123, Training Accuracy: 0.8844
# Epoch [40/250], Testing Loss: 0.0126, Testing Accuracy: 0.8821
# Epoch [41/250], Training Loss: 0.0123, Training Accuracy: 0.8844
# Epoch [41/250], Testing Loss: 0.0126, Testing Accuracy: 0.8818
# Epoch [42/250], Training Loss: 0.0123, Training Accuracy: 0.8845
# Epoch [42/250], Testing Loss: 0.0126, Testing Accuracy: 0.8819
# Epoch [43/250], Training Loss: 0.0123, Training Accuracy: 0.8845
# Epoch [43/250], Testing Loss: 0.0126, Testing Accuracy: 0.8818
# Epoch [44/250], Training Loss: 0.0123, Training Accuracy: 0.8844
# Epoch [44/250], Testing Loss: 0.0126, Testing Accuracy: 0.8818
# Epoch [45/250], Training Loss: 0.0123, Training Accuracy: 0.8844
# Epoch [45/250], Testing Loss: 0.0126, Testing Accuracy: 0.8820
# Epoch [46/250], Training Loss: 0.0123, Training Accuracy: 0.8844
# Epoch [46/250], Testing Loss: 0.0126, Testing Accuracy: 0.8818
# Epoch [47/250], Training Loss: 0.0123, Training Accuracy: 0.8845
# Epoch [47/250], Testing Loss: 0.0126, Testing Accuracy: 0.8819
# Epoch [48/250], Training Loss: 0.0123, Training Accuracy: 0.8844
# Epoch [48/250], Testing Loss: 0.0126, Testing Accuracy: 0.8819
# Epoch [49/250], Training Loss: 0.0123, Training Accuracy: 0.8845
# Epoch [49/250], Testing Loss: 0.0126, Testing Accuracy: 0.8823
# Epoch [50/250], Training Loss: 0.0123, Training Accuracy: 0.8845
# Epoch [50/250], Testing Loss: 0.0126, Testing Accuracy: 0.8818
# Epoch [51/250], Training Loss: 0.0123, Training Accuracy: 0.8844
# Epoch [51/250], Testing Loss: 0.0126, Testing Accuracy: 0.8818
# Epoch [52/250], Training Loss: 0.0123, Training Accuracy: 0.8844
# Epoch [52/250], Testing Loss: 0.0126, Testing Accuracy: 0.8820
# Epoch [53/250], Training Loss: 0.0123, Training Accuracy: 0.8845
# Epoch [53/250], Testing Loss: 0.0126, Testing Accuracy: 0.8818
# Epoch [54/250], Training Loss: 0.0123, Training Accuracy: 0.8845
# Epoch [54/250], Testing Loss: 0.0126, Testing Accuracy: 0.8821
# Epoch [55/250], Training Loss: 0.0123, Training Accuracy: 0.8845
# Epoch [55/250], Testing Loss: 0.0126, Testing Accuracy: 0.8821
# Epoch [56/250], Training Loss: 0.0123, Training Accuracy: 0.8844
# Epoch [56/250], Testing Loss: 0.0126, Testing Accuracy: 0.8821
# Epoch [57/250], Training Loss: 0.0123, Training Accuracy: 0.8845
# Epoch [57/250], Testing Loss: 0.0126, Testing Accuracy: 0.8820
# Epoch [58/250], Training Loss: 0.0123, Training Accuracy: 0.8845
# Epoch [58/250], Testing Loss: 0.0126, Testing Accuracy: 0.8821
# Epoch [59/250], Training Loss: 0.0123, Training Accuracy: 0.8845
# Epoch [59/250], Testing Loss: 0.0126, Testing Accuracy: 0.8820
# Epoch [60/250], Training Loss: 0.0123, Training Accuracy: 0.8846
# Epoch [60/250], Testing Loss: 0.0126, Testing Accuracy: 0.8820
# Epoch [61/250], Training Loss: 0.0123, Training Accuracy: 0.8844
# Epoch [61/250], Testing Loss: 0.0126, Testing Accuracy: 0.8821
# Epoch [62/250], Training Loss: 0.0123, Training Accuracy: 0.8845
# Epoch [62/250], Testing Loss: 0.0126, Testing Accuracy: 0.8817
# Epoch [63/250], Training Loss: 0.0123, Training Accuracy: 0.8846
# Epoch [63/250], Testing Loss: 0.0126, Testing Accuracy: 0.8820
# Epoch [64/250], Training Loss: 0.0123, Training Accuracy: 0.8845
# Epoch [64/250], Testing Loss: 0.0126, Testing Accuracy: 0.8820
# Epoch [65/250], Training Loss: 0.0123, Training Accuracy: 0.8845
# Epoch [65/250], Testing Loss: 0.0126, Testing Accuracy: 0.8820
# Epoch [66/250], Training Loss: 0.0123, Training Accuracy: 0.8846
# Epoch [66/250], Testing Loss: 0.0126, Testing Accuracy: 0.8821
# Epoch [67/250], Training Loss: 0.0123, Training Accuracy: 0.8845
# Epoch [67/250], Testing Loss: 0.0126, Testing Accuracy: 0.8817
# Epoch [68/250], Training Loss: 0.0123, Training Accuracy: 0.8846
# Epoch [68/250], Testing Loss: 0.0126, Testing Accuracy: 0.8823
# Epoch [69/250], Training Loss: 0.0123, Training Accuracy: 0.8845
# Epoch [69/250], Testing Loss: 0.0126, Testing Accuracy: 0.8820
# Epoch [70/250], Training Loss: 0.0123, Training Accuracy: 0.8846
# Epoch [70/250], Testing Loss: 0.0126, Testing Accuracy: 0.8820
# Epoch [71/250], Training Loss: 0.0123, Training Accuracy: 0.8846
# Epoch [71/250], Testing Loss: 0.0126, Testing Accuracy: 0.8819
# Epoch [72/250], Training Loss: 0.0123, Training Accuracy: 0.8846
# Epoch [72/250], Testing Loss: 0.0126, Testing Accuracy: 0.8820
# Epoch [73/250], Training Loss: 0.0123, Training Accuracy: 0.8846
# Epoch [73/250], Testing Loss: 0.0126, Testing Accuracy: 0.8820
# Epoch [74/250], Training Loss: 0.0123, Training Accuracy: 0.8846
# Epoch [74/250], Testing Loss: 0.0126, Testing Accuracy: 0.8818
# Epoch [75/250], Training Loss: 0.0123, Training Accuracy: 0.8846
# Epoch [75/250], Testing Loss: 0.0126, Testing Accuracy: 0.8820
# Epoch [76/250], Training Loss: 0.0123, Training Accuracy: 0.8845
# Epoch [76/250], Testing Loss: 0.0126, Testing Accuracy: 0.8817
# Epoch [77/250], Training Loss: 0.0123, Training Accuracy: 0.8846
# Epoch [77/250], Testing Loss: 0.0126, Testing Accuracy: 0.8820
# Epoch [78/250], Training Loss: 0.0123, Training Accuracy: 0.8846
# Epoch [78/250], Testing Loss: 0.0126, Testing Accuracy: 0.8821
# Epoch [79/250], Training Loss: 0.0123, Training Accuracy: 0.8847
# Epoch [79/250], Testing Loss: 0.0126, Testing Accuracy: 0.8821
# Epoch [80/250], Training Loss: 0.0123, Training Accuracy: 0.8845
# Epoch [80/250], Testing Loss: 0.0126, Testing Accuracy: 0.8821
# Epoch [81/250], Training Loss: 0.0123, Training Accuracy: 0.8846
# Epoch [81/250], Testing Loss: 0.0126, Testing Accuracy: 0.8819
# Epoch [82/250], Training Loss: 0.0123, Training Accuracy: 0.8846
# Epoch [82/250], Testing Loss: 0.0126, Testing Accuracy: 0.8821
# Epoch [83/250], Training Loss: 0.0123, Training Accuracy: 0.8846
# Epoch [83/250], Testing Loss: 0.0126, Testing Accuracy: 0.8821
# Epoch [84/250], Training Loss: 0.0123, Training Accuracy: 0.8846
# Epoch [84/250], Testing Loss: 0.0126, Testing Accuracy: 0.8822
# Epoch [85/250], Training Loss: 0.0123, Training Accuracy: 0.8846
# Epoch [85/250], Testing Loss: 0.0126, Testing Accuracy: 0.8820
# Epoch [86/250], Training Loss: 0.0123, Training Accuracy: 0.8846
# Epoch [86/250], Testing Loss: 0.0126, Testing Accuracy: 0.8817
# Epoch [87/250], Training Loss: 0.0123, Training Accuracy: 0.8846
# Epoch [87/250], Testing Loss: 0.0126, Testing Accuracy: 0.8821
# Epoch [88/250], Training Loss: 0.0123, Training Accuracy: 0.8846
# Epoch [88/250], Testing Loss: 0.0126, Testing Accuracy: 0.8821
# Epoch [89/250], Training Loss: 0.0123, Training Accuracy: 0.8847
# Epoch [89/250], Testing Loss: 0.0126, Testing Accuracy: 0.8822
# Epoch [90/250], Training Loss: 0.0123, Training Accuracy: 0.8847
# Epoch [90/250], Testing Loss: 0.0126, Testing Accuracy: 0.8821
# Epoch [91/250], Training Loss: 0.0123, Training Accuracy: 0.8847
# Epoch [91/250], Testing Loss: 0.0126, Testing Accuracy: 0.8822
# Epoch [92/250], Training Loss: 0.0123, Training Accuracy: 0.8846
# Epoch [92/250], Testing Loss: 0.0126, Testing Accuracy: 0.8821
# Epoch [93/250], Training Loss: 0.0123, Training Accuracy: 0.8846
# Epoch [93/250], Testing Loss: 0.0126, Testing Accuracy: 0.8819
# Epoch [94/250], Training Loss: 0.0123, Training Accuracy: 0.8846
# Epoch [94/250], Testing Loss: 0.0126, Testing Accuracy: 0.8821
# Epoch [95/250], Training Loss: 0.0123, Training Accuracy: 0.8847
# Epoch [95/250], Testing Loss: 0.0126, Testing Accuracy: 0.8821
# Epoch [96/250], Training Loss: 0.0123, Training Accuracy: 0.8846
# Epoch [96/250], Testing Loss: 0.0126, Testing Accuracy: 0.8822
# Epoch [97/250], Training Loss: 0.0123, Training Accuracy: 0.8846
# Epoch [97/250], Testing Loss: 0.0126, Testing Accuracy: 0.8823
# Epoch [98/250], Training Loss: 0.0123, Training Accuracy: 0.8846
# Epoch [98/250], Testing Loss: 0.0126, Testing Accuracy: 0.8820
# Epoch [99/250], Training Loss: 0.0123, Training Accuracy: 0.8847
# Epoch [99/250], Testing Loss: 0.0126, Testing Accuracy: 0.8820
# Epoch [100/250], Training Loss: 0.0123, Training Accuracy: 0.8847
# Epoch [100/250], Testing Loss: 0.0126, Testing Accuracy: 0.8822
# Epoch [101/250], Training Loss: 0.0123, Training Accuracy: 0.8846
# Epoch [101/250], Testing Loss: 0.0126, Testing Accuracy: 0.8821
# Epoch [102/250], Training Loss: 0.0123, Training Accuracy: 0.8846
# Epoch [102/250], Testing Loss: 0.0126, Testing Accuracy: 0.8821
# Epoch [103/250], Training Loss: 0.0123, Training Accuracy: 0.8846
# Epoch [103/250], Testing Loss: 0.0126, Testing Accuracy: 0.8819
# Epoch [104/250], Training Loss: 0.0123, Training Accuracy: 0.8847
# Epoch [104/250], Testing Loss: 0.0126, Testing Accuracy: 0.8820
# Epoch [105/250], Training Loss: 0.0123, Training Accuracy: 0.8847
# Epoch [105/250], Testing Loss: 0.0126, Testing Accuracy: 0.8819
# Epoch [106/250], Training Loss: 0.0123, Training Accuracy: 0.8846
# Epoch [106/250], Testing Loss: 0.0126, Testing Accuracy: 0.8820
# Epoch [107/250], Training Loss: 0.0123, Training Accuracy: 0.8847
# Epoch [107/250], Testing Loss: 0.0126, Testing Accuracy: 0.8821
# Epoch [108/250], Training Loss: 0.0123, Training Accuracy: 0.8846
# Epoch [108/250], Testing Loss: 0.0126, Testing Accuracy: 0.8820
# Epoch [109/250], Training Loss: 0.0123, Training Accuracy: 0.8847
# Epoch [109/250], Testing Loss: 0.0126, Testing Accuracy: 0.8819
# Epoch [110/250], Training Loss: 0.0123, Training Accuracy: 0.8847
# Epoch [110/250], Testing Loss: 0.0126, Testing Accuracy: 0.8820
# Epoch [111/250], Training Loss: 0.0123, Training Accuracy: 0.8847
# Epoch [111/250], Testing Loss: 0.0126, Testing Accuracy: 0.8821
# Epoch [112/250], Training Loss: 0.0123, Training Accuracy: 0.8846
# Epoch [112/250], Testing Loss: 0.0126, Testing Accuracy: 0.8820
# Epoch [113/250], Training Loss: 0.0123, Training Accuracy: 0.8846
# Epoch [113/250], Testing Loss: 0.0126, Testing Accuracy: 0.8818
# Epoch [114/250], Training Loss: 0.0123, Training Accuracy: 0.8846
# Epoch [114/250], Testing Loss: 0.0126, Testing Accuracy: 0.8822
# Epoch [115/250], Training Loss: 0.0123, Training Accuracy: 0.8846
# Epoch [115/250], Testing Loss: 0.0126, Testing Accuracy: 0.8822
# Epoch [116/250], Training Loss: 0.0123, Training Accuracy: 0.8847
# Epoch [116/250], Testing Loss: 0.0126, Testing Accuracy: 0.8819
# Epoch [117/250], Training Loss: 0.0123, Training Accuracy: 0.8847
# Epoch [117/250], Testing Loss: 0.0126, Testing Accuracy: 0.8821
# Epoch [118/250], Training Loss: 0.0123, Training Accuracy: 0.8847
# Epoch [118/250], Testing Loss: 0.0126, Testing Accuracy: 0.8819
# Epoch [119/250], Training Loss: 0.0123, Training Accuracy: 0.8847
# Epoch [119/250], Testing Loss: 0.0126, Testing Accuracy: 0.8819
# Epoch [120/250], Training Loss: 0.0123, Training Accuracy: 0.8847
# Epoch [120/250], Testing Loss: 0.0126, Testing Accuracy: 0.8819
# Epoch [121/250], Training Loss: 0.0123, Training Accuracy: 0.8847
# Epoch [121/250], Testing Loss: 0.0126, Testing Accuracy: 0.8819
# Epoch [122/250], Training Loss: 0.0123, Training Accuracy: 0.8847
# Epoch [122/250], Testing Loss: 0.0126, Testing Accuracy: 0.8821
# Epoch [123/250], Training Loss: 0.0123, Training Accuracy: 0.8847
# Epoch [123/250], Testing Loss: 0.0126, Testing Accuracy: 0.8817
# Epoch [124/250], Training Loss: 0.0123, Training Accuracy: 0.8847
# Epoch [124/250], Testing Loss: 0.0126, Testing Accuracy: 0.8819
# Epoch [125/250], Training Loss: 0.0123, Training Accuracy: 0.8847
# Epoch [125/250], Testing Loss: 0.0126, Testing Accuracy: 0.8820
# Epoch [126/250], Training Loss: 0.0123, Training Accuracy: 0.8847
# Epoch [126/250], Testing Loss: 0.0126, Testing Accuracy: 0.8822
# Epoch [127/250], Training Loss: 0.0123, Training Accuracy: 0.8847
# Epoch [127/250], Testing Loss: 0.0126, Testing Accuracy: 0.8820
# Epoch [128/250], Training Loss: 0.0123, Training Accuracy: 0.8847
# Epoch [128/250], Testing Loss: 0.0126, Testing Accuracy: 0.8820
# Epoch [129/250], Training Loss: 0.0123, Training Accuracy: 0.8847
# Epoch [129/250], Testing Loss: 0.0126, Testing Accuracy: 0.8821
# Epoch [130/250], Training Loss: 0.0123, Training Accuracy: 0.8847
# Epoch [130/250], Testing Loss: 0.0126, Testing Accuracy: 0.8821
# Epoch [131/250], Training Loss: 0.0123, Training Accuracy: 0.8847
# Epoch [131/250], Testing Loss: 0.0126, Testing Accuracy: 0.8818
# Epoch [132/250], Training Loss: 0.0123, Training Accuracy: 0.8847
# Epoch [132/250], Testing Loss: 0.0126, Testing Accuracy: 0.8822
# Epoch [133/250], Training Loss: 0.0123, Training Accuracy: 0.8846
# Epoch [133/250], Testing Loss: 0.0126, Testing Accuracy: 0.8820
# Epoch [134/250], Training Loss: 0.0123, Training Accuracy: 0.8847
# Epoch [134/250], Testing Loss: 0.0126, Testing Accuracy: 0.8819
# Epoch [135/250], Training Loss: 0.0123, Training Accuracy: 0.8847
# Epoch [135/250], Testing Loss: 0.0126, Testing Accuracy: 0.8819
# Epoch [136/250], Training Loss: 0.0123, Training Accuracy: 0.8847
# Epoch [136/250], Testing Loss: 0.0126, Testing Accuracy: 0.8822
# Epoch [137/250], Training Loss: 0.0123, Training Accuracy: 0.8847
# Epoch [137/250], Testing Loss: 0.0126, Testing Accuracy: 0.8819
# Epoch [138/250], Training Loss: 0.0123, Training Accuracy: 0.8848
# Epoch [138/250], Testing Loss: 0.0126, Testing Accuracy: 0.8821
# Epoch [139/250], Training Loss: 0.0123, Training Accuracy: 0.8847
# Epoch [139/250], Testing Loss: 0.0126, Testing Accuracy: 0.8820
# Epoch [140/250], Training Loss: 0.0123, Training Accuracy: 0.8847
# Epoch [140/250], Testing Loss: 0.0126, Testing Accuracy: 0.8821
# Epoch [141/250], Training Loss: 0.0123, Training Accuracy: 0.8847
# Epoch [141/250], Testing Loss: 0.0126, Testing Accuracy: 0.8822
# Epoch [142/250], Training Loss: 0.0123, Training Accuracy: 0.8847
# Epoch [142/250], Testing Loss: 0.0126, Testing Accuracy: 0.8822
# Epoch [143/250], Training Loss: 0.0123, Training Accuracy: 0.8847
# Epoch [143/250], Testing Loss: 0.0126, Testing Accuracy: 0.8819
# Epoch [144/250], Training Loss: 0.0123, Training Accuracy: 0.8847
# Epoch [144/250], Testing Loss: 0.0126, Testing Accuracy: 0.8821
# Epoch [145/250], Training Loss: 0.0123, Training Accuracy: 0.8847
# Epoch [145/250], Testing Loss: 0.0126, Testing Accuracy: 0.8822
# Epoch [146/250], Training Loss: 0.0123, Training Accuracy: 0.8848
# Epoch [146/250], Testing Loss: 0.0126, Testing Accuracy: 0.8819
# Epoch [147/250], Training Loss: 0.0123, Training Accuracy: 0.8847
# Epoch [147/250], Testing Loss: 0.0126, Testing Accuracy: 0.8821
# Epoch [148/250], Training Loss: 0.0123, Training Accuracy: 0.8847
# Epoch [148/250], Testing Loss: 0.0126, Testing Accuracy: 0.8819
# Epoch [149/250], Training Loss: 0.0123, Training Accuracy: 0.8847
# Epoch [149/250], Testing Loss: 0.0126, Testing Accuracy: 0.8821
# Epoch [150/250], Training Loss: 0.0123, Training Accuracy: 0.8847
# Epoch [150/250], Testing Loss: 0.0126, Testing Accuracy: 0.8819
# Epoch [151/250], Training Loss: 0.0123, Training Accuracy: 0.8847
# Epoch [151/250], Testing Loss: 0.0126, Testing Accuracy: 0.8821
# Epoch [152/250], Training Loss: 0.0123, Training Accuracy: 0.8847
# Epoch [152/250], Testing Loss: 0.0126, Testing Accuracy: 0.8821
# Epoch [153/250], Training Loss: 0.0123, Training Accuracy: 0.8847
# Epoch [153/250], Testing Loss: 0.0126, Testing Accuracy: 0.8820
# Epoch [154/250], Training Loss: 0.0123, Training Accuracy: 0.8847
# Epoch [154/250], Testing Loss: 0.0126, Testing Accuracy: 0.8819
# Epoch [155/250], Training Loss: 0.0123, Training Accuracy: 0.8847
# Epoch [155/250], Testing Loss: 0.0126, Testing Accuracy: 0.8818
# Epoch [156/250], Training Loss: 0.0123, Training Accuracy: 0.8847
# Epoch [156/250], Testing Loss: 0.0126, Testing Accuracy: 0.8820
# Epoch [157/250], Training Loss: 0.0123, Training Accuracy: 0.8847
# Epoch [157/250], Testing Loss: 0.0126, Testing Accuracy: 0.8821
# Epoch [158/250], Training Loss: 0.0123, Training Accuracy: 0.8847
# Epoch [158/250], Testing Loss: 0.0126, Testing Accuracy: 0.8820
# Epoch [159/250], Training Loss: 0.0123, Training Accuracy: 0.8847
# Epoch [159/250], Testing Loss: 0.0126, Testing Accuracy: 0.8821
# Epoch [160/250], Training Loss: 0.0123, Training Accuracy: 0.8847
# Epoch [160/250], Testing Loss: 0.0126, Testing Accuracy: 0.8817
# Epoch [161/250], Training Loss: 0.0123, Training Accuracy: 0.8847
# Epoch [161/250], Testing Loss: 0.0126, Testing Accuracy: 0.8821
# Epoch [162/250], Training Loss: 0.0123, Training Accuracy: 0.8847
# Epoch [162/250], Testing Loss: 0.0126, Testing Accuracy: 0.8821
# Epoch [163/250], Training Loss: 0.0123, Training Accuracy: 0.8848
# Epoch [163/250], Testing Loss: 0.0126, Testing Accuracy: 0.8818
# Epoch [164/250], Training Loss: 0.0123, Training Accuracy: 0.8847
# Epoch [164/250], Testing Loss: 0.0126, Testing Accuracy: 0.8817
# Epoch [165/250], Training Loss: 0.0123, Training Accuracy: 0.8847
# Epoch [165/250], Testing Loss: 0.0126, Testing Accuracy: 0.8816
# Epoch [166/250], Training Loss: 0.0123, Training Accuracy: 0.8847
# Epoch [166/250], Testing Loss: 0.0126, Testing Accuracy: 0.8819
# Epoch [167/250], Training Loss: 0.0123, Training Accuracy: 0.8847
# Epoch [167/250], Testing Loss: 0.0126, Testing Accuracy: 0.8821
# Epoch [168/250], Training Loss: 0.0123, Training Accuracy: 0.8848
# Epoch [168/250], Testing Loss: 0.0126, Testing Accuracy: 0.8817
# Epoch [169/250], Training Loss: 0.0122, Training Accuracy: 0.8847
# Epoch [169/250], Testing Loss: 0.0126, Testing Accuracy: 0.8821
# Epoch [170/250], Training Loss: 0.0123, Training Accuracy: 0.8847
# Epoch [170/250], Testing Loss: 0.0126, Testing Accuracy: 0.8821
# Epoch [171/250], Training Loss: 0.0123, Training Accuracy: 0.8847
# Epoch [171/250], Testing Loss: 0.0126, Testing Accuracy: 0.8820
# Epoch [172/250], Training Loss: 0.0122, Training Accuracy: 0.8848
# Epoch [172/250], Testing Loss: 0.0126, Testing Accuracy: 0.8820
# Epoch [173/250], Training Loss: 0.0123, Training Accuracy: 0.8847
# Epoch [173/250], Testing Loss: 0.0126, Testing Accuracy: 0.8821
# Epoch [174/250], Training Loss: 0.0122, Training Accuracy: 0.8848
# Epoch [174/250], Testing Loss: 0.0126, Testing Accuracy: 0.8822
# Epoch [175/250], Training Loss: 0.0122, Training Accuracy: 0.8847
# Epoch [175/250], Testing Loss: 0.0126, Testing Accuracy: 0.8821
# Epoch [176/250], Training Loss: 0.0122, Training Accuracy: 0.8847
# Epoch [176/250], Testing Loss: 0.0126, Testing Accuracy: 0.8818
# Epoch [177/250], Training Loss: 0.0122, Training Accuracy: 0.8847
# Epoch [177/250], Testing Loss: 0.0126, Testing Accuracy: 0.8821
# Epoch [178/250], Training Loss: 0.0122, Training Accuracy: 0.8848
# Epoch [178/250], Testing Loss: 0.0126, Testing Accuracy: 0.8821
# Epoch [179/250], Training Loss: 0.0122, Training Accuracy: 0.8848
# Epoch [179/250], Testing Loss: 0.0126, Testing Accuracy: 0.8821
# Epoch [180/250], Training Loss: 0.0122, Training Accuracy: 0.8847
# Epoch [180/250], Testing Loss: 0.0126, Testing Accuracy: 0.8820
# Epoch [181/250], Training Loss: 0.0122, Training Accuracy: 0.8848
# Epoch [181/250], Testing Loss: 0.0126, Testing Accuracy: 0.8821
# Epoch [182/250], Training Loss: 0.0122, Training Accuracy: 0.8847
# Epoch [182/250], Testing Loss: 0.0126, Testing Accuracy: 0.8821
# Epoch [183/250], Training Loss: 0.0122, Training Accuracy: 0.8848
# Epoch [183/250], Testing Loss: 0.0126, Testing Accuracy: 0.8818
# Epoch [184/250], Training Loss: 0.0122, Training Accuracy: 0.8848
# Epoch [184/250], Testing Loss: 0.0126, Testing Accuracy: 0.8820
# Epoch [185/250], Training Loss: 0.0122, Training Accuracy: 0.8848
# Epoch [185/250], Testing Loss: 0.0126, Testing Accuracy: 0.8817
# Epoch [186/250], Training Loss: 0.0122, Training Accuracy: 0.8848
# Epoch [186/250], Testing Loss: 0.0126, Testing Accuracy: 0.8818
# Epoch [187/250], Training Loss: 0.0122, Training Accuracy: 0.8847
# Epoch [187/250], Testing Loss: 0.0126, Testing Accuracy: 0.8818
# Epoch [188/250], Training Loss: 0.0122, Training Accuracy: 0.8848
# Epoch [188/250], Testing Loss: 0.0126, Testing Accuracy: 0.8822
# Epoch [189/250], Training Loss: 0.0122, Training Accuracy: 0.8847
# Epoch [189/250], Testing Loss: 0.0126, Testing Accuracy: 0.8819
# Epoch [190/250], Training Loss: 0.0122, Training Accuracy: 0.8848
# Epoch [190/250], Testing Loss: 0.0126, Testing Accuracy: 0.8822
# Epoch [191/250], Training Loss: 0.0122, Training Accuracy: 0.8848
# Epoch [191/250], Testing Loss: 0.0126, Testing Accuracy: 0.8818
# Epoch [192/250], Training Loss: 0.0122, Training Accuracy: 0.8848
# Epoch [192/250], Testing Loss: 0.0127, Testing Accuracy: 0.8818
# Epoch [193/250], Training Loss: 0.0122, Training Accuracy: 0.8847
# Epoch [193/250], Testing Loss: 0.0126, Testing Accuracy: 0.8822
# Epoch [194/250], Training Loss: 0.0122, Training Accuracy: 0.8848
# Epoch [194/250], Testing Loss: 0.0126, Testing Accuracy: 0.8821
# Epoch [195/250], Training Loss: 0.0122, Training Accuracy: 0.8848
# Epoch [195/250], Testing Loss: 0.0126, Testing Accuracy: 0.8821
# Epoch [196/250], Training Loss: 0.0122, Training Accuracy: 0.8848
# Epoch [196/250], Testing Loss: 0.0127, Testing Accuracy: 0.8815
# Epoch [197/250], Training Loss: 0.0122, Training Accuracy: 0.8847
# Epoch [197/250], Testing Loss: 0.0126, Testing Accuracy: 0.8819
# Epoch [198/250], Training Loss: 0.0122, Training Accuracy: 0.8848
# Epoch [198/250], Testing Loss: 0.0126, Testing Accuracy: 0.8819
# Epoch [199/250], Training Loss: 0.0122, Training Accuracy: 0.8848
# Epoch [199/250], Testing Loss: 0.0126, Testing Accuracy: 0.8820
# Epoch [200/250], Training Loss: 0.0122, Training Accuracy: 0.8848
# Epoch [200/250], Testing Loss: 0.0126, Testing Accuracy: 0.8818
# Epoch [201/250], Training Loss: 0.0122, Training Accuracy: 0.8848
# Epoch [201/250], Testing Loss: 0.0126, Testing Accuracy: 0.8821
# Epoch [202/250], Training Loss: 0.0122, Training Accuracy: 0.8848
# Epoch [202/250], Testing Loss: 0.0126, Testing Accuracy: 0.8821
# Epoch [203/250], Training Loss: 0.0122, Training Accuracy: 0.8847
# Epoch [203/250], Testing Loss: 0.0127, Testing Accuracy: 0.8819
# Epoch [204/250], Training Loss: 0.0122, Training Accuracy: 0.8847
# Epoch [204/250], Testing Loss: 0.0126, Testing Accuracy: 0.8821
# Epoch [205/250], Training Loss: 0.0122, Training Accuracy: 0.8848
# Epoch [205/250], Testing Loss: 0.0126, Testing Accuracy: 0.8819
# Epoch [206/250], Training Loss: 0.0122, Training Accuracy: 0.8847
# Epoch [206/250], Testing Loss: 0.0127, Testing Accuracy: 0.8819
# Epoch [207/250], Training Loss: 0.0122, Training Accuracy: 0.8848
# Epoch [207/250], Testing Loss: 0.0126, Testing Accuracy: 0.8819
# Epoch [208/250], Training Loss: 0.0122, Training Accuracy: 0.8848
# Epoch [208/250], Testing Loss: 0.0126, Testing Accuracy: 0.8818
# Epoch [209/250], Training Loss: 0.0122, Training Accuracy: 0.8848
# Epoch [209/250], Testing Loss: 0.0126, Testing Accuracy: 0.8820
# Epoch [210/250], Training Loss: 0.0122, Training Accuracy: 0.8848
# Epoch [210/250], Testing Loss: 0.0126, Testing Accuracy: 0.8819
# Epoch [211/250], Training Loss: 0.0122, Training Accuracy: 0.8848
# Epoch [211/250], Testing Loss: 0.0126, Testing Accuracy: 0.8818
# Epoch [212/250], Training Loss: 0.0122, Training Accuracy: 0.8847
# Epoch [212/250], Testing Loss: 0.0126, Testing Accuracy: 0.8821
# Epoch [213/250], Training Loss: 0.0122, Training Accuracy: 0.8848
# Epoch [213/250], Testing Loss: 0.0127, Testing Accuracy: 0.8815
# Epoch [214/250], Training Loss: 0.0122, Training Accuracy: 0.8848
# Epoch [214/250], Testing Loss: 0.0127, Testing Accuracy: 0.8820
# Epoch [215/250], Training Loss: 0.0122, Training Accuracy: 0.8848
# Epoch [215/250], Testing Loss: 0.0127, Testing Accuracy: 0.8819
# Epoch [216/250], Training Loss: 0.0122, Training Accuracy: 0.8848
# Epoch [216/250], Testing Loss: 0.0127, Testing Accuracy: 0.8819
# Epoch [217/250], Training Loss: 0.0122, Training Accuracy: 0.8848
# Epoch [217/250], Testing Loss: 0.0127, Testing Accuracy: 0.8819
# Epoch [218/250], Training Loss: 0.0122, Training Accuracy: 0.8847
# Epoch [218/250], Testing Loss: 0.0126, Testing Accuracy: 0.8821
# Epoch [219/250], Training Loss: 0.0122, Training Accuracy: 0.8848
# Epoch [219/250], Testing Loss: 0.0127, Testing Accuracy: 0.8819
# Epoch [220/250], Training Loss: 0.0122, Training Accuracy: 0.8848
# Epoch [220/250], Testing Loss: 0.0126, Testing Accuracy: 0.8818
# Epoch [221/250], Training Loss: 0.0122, Training Accuracy: 0.8848
# Epoch [221/250], Testing Loss: 0.0126, Testing Accuracy: 0.8820
# Epoch [222/250], Training Loss: 0.0122, Training Accuracy: 0.8847
# Epoch [222/250], Testing Loss: 0.0127, Testing Accuracy: 0.8820
# Epoch [223/250], Training Loss: 0.0122, Training Accuracy: 0.8848
# Epoch [223/250], Testing Loss: 0.0127, Testing Accuracy: 0.8820
# Epoch [224/250], Training Loss: 0.0122, Training Accuracy: 0.8849
# Epoch [224/250], Testing Loss: 0.0127, Testing Accuracy: 0.8818
# Epoch [225/250], Training Loss: 0.0122, Training Accuracy: 0.8848
# Epoch [225/250], Testing Loss: 0.0127, Testing Accuracy: 0.8821
# Epoch [226/250], Training Loss: 0.0122, Training Accuracy: 0.8849
# Epoch [226/250], Testing Loss: 0.0127, Testing Accuracy: 0.8816
# Epoch [227/250], Training Loss: 0.0122, Training Accuracy: 0.8848
# Epoch [227/250], Testing Loss: 0.0127, Testing Accuracy: 0.8818
# Epoch [228/250], Training Loss: 0.0122, Training Accuracy: 0.8848
# Epoch [228/250], Testing Loss: 0.0127, Testing Accuracy: 0.8821
# Epoch [229/250], Training Loss: 0.0122, Training Accuracy: 0.8848
# Epoch [229/250], Testing Loss: 0.0126, Testing Accuracy: 0.8819
# Epoch [230/250], Training Loss: 0.0122, Training Accuracy: 0.8848
# Epoch [230/250], Testing Loss: 0.0127, Testing Accuracy: 0.8820
# Epoch [231/250], Training Loss: 0.0122, Training Accuracy: 0.8848
# Epoch [231/250], Testing Loss: 0.0127, Testing Accuracy: 0.8817
# Epoch [232/250], Training Loss: 0.0122, Training Accuracy: 0.8848
# Epoch [232/250], Testing Loss: 0.0127, Testing Accuracy: 0.8819
# Epoch [233/250], Training Loss: 0.0122, Training Accuracy: 0.8848
# Epoch [233/250], Testing Loss: 0.0126, Testing Accuracy: 0.8817
# Epoch [234/250], Training Loss: 0.0122, Training Accuracy: 0.8848
# Epoch [234/250], Testing Loss: 0.0127, Testing Accuracy: 0.8820
# Epoch [235/250], Training Loss: 0.0122, Training Accuracy: 0.8849
# Epoch [235/250], Testing Loss: 0.0126, Testing Accuracy: 0.8818
# Epoch [236/250], Training Loss: 0.0122, Training Accuracy: 0.8848
# Epoch [236/250], Testing Loss: 0.0127, Testing Accuracy: 0.8819
# Epoch [237/250], Training Loss: 0.0122, Training Accuracy: 0.8848
# Epoch [237/250], Testing Loss: 0.0127, Testing Accuracy: 0.8820
# Epoch [238/250], Training Loss: 0.0122, Training Accuracy: 0.8849
# Epoch [238/250], Testing Loss: 0.0126, Testing Accuracy: 0.8819
# Epoch [239/250], Training Loss: 0.0122, Training Accuracy: 0.8848
# Epoch [239/250], Testing Loss: 0.0127, Testing Accuracy: 0.8820
# Epoch [240/250], Training Loss: 0.0122, Training Accuracy: 0.8848
# Epoch [240/250], Testing Loss: 0.0127, Testing Accuracy: 0.8818
# Epoch [241/250], Training Loss: 0.0122, Training Accuracy: 0.8848
# Epoch [241/250], Testing Loss: 0.0126, Testing Accuracy: 0.8821
# Epoch [242/250], Training Loss: 0.0122, Training Accuracy: 0.8849
# Epoch [242/250], Testing Loss: 0.0127, Testing Accuracy: 0.8818
# Epoch [243/250], Training Loss: 0.0122, Training Accuracy: 0.8849
# Epoch [243/250], Testing Loss: 0.0127, Testing Accuracy: 0.8818
# Epoch [244/250], Training Loss: 0.0122, Training Accuracy: 0.8849
# Epoch [244/250], Testing Loss: 0.0127, Testing Accuracy: 0.8819
# Epoch [245/250], Training Loss: 0.0122, Training Accuracy: 0.8849
# Epoch [245/250], Testing Loss: 0.0127, Testing Accuracy: 0.8820
# Epoch [246/250], Training Loss: 0.0122, Training Accuracy: 0.8849
# Epoch [246/250], Testing Loss: 0.0127, Testing Accuracy: 0.8818
# Epoch [247/250], Training Loss: 0.0122, Training Accuracy: 0.8848
# Epoch [247/250], Testing Loss: 0.0127, Testing Accuracy: 0.8819
# Epoch [248/250], Training Loss: 0.0122, Training Accuracy: 0.8848
# Epoch [248/250], Testing Loss: 0.0127, Testing Accuracy: 0.8817
# Epoch [249/250], Training Loss: 0.0122, Training Accuracy: 0.8849
# Epoch [249/250], Testing Loss: 0.0127, Testing Accuracy: 0.8819
# Epoch [250/250], Training Loss: 0.0122, Training Accuracy: 0.8849
# Epoch [250/250], Testing Loss: 0.0127, Testing Accuracy: 0.8818

# %%
# Save the trained model
torch.save(model.state_dict(), 'data.pth')
